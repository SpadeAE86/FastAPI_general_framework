# %%
print("hello world")
# Out:
# hello world

# %%
record1 = (9.66415476799011, 979)  #mov
upload1 = (22.745585441589355, 979)  #jpg

record2 = (0.679551362991333, 121)
upload2 = (0.8121025562286377, 0.0067)

# %% [markdown]
# Ffmpeg Report
